# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
# !pip install pydataset
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ...
# WARNING: You are using pip version 20.0.2; however, version 20.1 is available.
# You should consider upgrading via the '/Users/lucasdu/Documents/Faculdade/gerenciamento_dados_info/aitividade07/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# #### Exercício 01. Faça um head() dos conjuntos de dados.

# %%
copacabana = pd.read_csv('../data/Aula08_USJT_2020_GERDADOS-atividade7-copacabana.csv', delimiter=';')
copacabana.head()
# Out:
#    Posicao  Quartos  Vagas  DistIpanema  DistPraia  DistFavela  RendaMedia  \
# 0        1      3.0   0.01         1144        311         146      969501
# 1        0      2.0   0.01         2456        502         254     1472861
# 2        0      2.0   0.01         2448        772         229     1803724
# 3        0      2.0   0.01         1615        428         310     1124331
# 4        0      2.0   1.00         2358        586         287     1165764
#
#    RendaMovel  RendaMovelRua  Vu2009  Mes  Idade  Tipologia  AreaConstruida  \
# 0     1028834         999168    1750  509   37.0          1              95
# 1     1137759        1305310    2300  484   30.0          1              71
# 2     1512475        1658100    2350  920   44.0          1              58
# 3     1370600        1247466    2200  930   43.0          1              88
# 4     1177933        1171849    2150  918   42.0          1              68
#
#    VAL_UNIT            X            Y
# ...

# %% [markdown]
# #### Exercício 02. Construa uma distribuição de freqüência completa para as variáveis categóricas dos conjuntos de dados.

# %%
posicao = [copacabana[copacabana['Posicao'] == 0]['Posicao'].count(),
         copacabana[copacabana['Posicao'] == 1]['Posicao'].count()
         ]
print(posicao)

tipologia = [copacabana[copacabana['Tipologia'] == 1]['Tipologia'].count(),
         copacabana[copacabana['Tipologia'] == 2]['Tipologia'].count(),
         copacabana[copacabana['Tipologia'] == 3]['Tipologia'].count()
         ]
print(tipologia)

fig = plt.figure(figsize=(20, 5))
gs = fig.add_gridspec(1, 2)

ax1=fig.add_subplot(gs[0,0])
ax1.set_title('Posicao')
sns.distplot(posicao, color="b")

ax2=fig.add_subplot(gs[0,1])
ax2.set_title('Tipologia')
sns.distplot(tipologia, color="r")
# Out:
# [667, 1008]
# [1599, 32, 44]

# %% [markdown]
# #### Exercício 03. Construa gráficos adequados para representar:
# #### b) Copacabana: preço X distância da praia; área construída X distância da praia

# %%
# preço X distância da praia
df_graf1 = copacabana[['DistPraia','VAL_UNIT']]

# área construída X distância da praia
df_graf2 = copacabana[['DistPraia','AreaConstruida']]

fig = plt.figure(figsize=(20, 5))
gs = fig.add_gridspec(1, 2)

ax1=fig.add_subplot(gs[0,0])
ax1.set_title('Preço X Distância da Praia')
sns.distplot(df_graf1, color='r', kde_kws={"label": "DistPraia"}, hist_kws={"label":"VAL_UNIT"})

ax2=fig.add_subplot(gs[0,1])
ax2.set_title('Área Construída X Distância da Praia')
sns.distplot(df_graf2, color='r', kde_kws={"label": "DistPraia"}, hist_kws={"label":"AreaConstruida"})

# %% [markdown]
# #### Exercício 04. Construa histogramas para:
# #### b) Copacabana: quartos

# %%
copacabana['Quartos'].plot.hist()

# %% [markdown]
# ####Exercício 05. Construa diagramas de ramos e folhas para:
#
# ####b) Copacabana: quartos
# ####Obs: use matplotlib.pyplot.stem

# %%
plt.stem(range(1,(len(copacabana['Quartos'])+1)), copacabana['Quartos'].tolist(), linefmt=':')
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# ####Exercício 06. Calcule a média aritmética para classe no Titanic e quartos no Copacabana.

# %%
copacabana['Quartos'].mean()
# Out:
# 1.767510447761194

# %% [markdown]
# #### Exercício 07. Calcule a moda para classe no Titanic e quartos no Copacabana.

# %%
copacabana['Quartos'].mode()
# Out:
# 0    1.0
# dtype: float64

# %% [markdown]
# #### Exercício 08. Calcule a mediana para classe no Titanic e quartos no Copacabana.

# %%
copacabana['Quartos'].median()
# Out:
# 2.0

# %% [markdown]
# #### Exercício 09. Calcule as medidas de dispersão para classe no Titanic e quartos no Copacabana.

# %%
copacabana['Quartos'].describe()
# Out:
# count    1675.000000
# mean        1.767510
# std         1.142523
# min         0.010000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         6.000000
# Name: Quartos, dtype: float64

# %% [markdown]
# #### Exercício 10. Determine e interprete as medidas de assimetria e curtose para classe no Titanic e quartos no Copacabana.

# %%
fig = plt.figure(figsize=(20, 5))
gs = fig.add_gridspec(1, 2)

ax1=fig.add_subplot(gs[0,0])
ax1.set_title('assimetria')
# assimetria
copacabana['Quartos'].plot()

ax2=fig.add_subplot(gs[0,1])
ax2.set_title('curtose')
# curtose
copacabana['Quartos'].plot.kde()

# %% [markdown]
# #### Exercício 11. Faça o gráfico Box Plot para classe no Titanic e quartos no Copacabana.

# %%
copacabana['Quartos'].plot.box()
